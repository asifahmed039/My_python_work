# %% [markdown]
# ## string
# ### any thing which we write is string  ex:- s1='Hello' s2="97834267268" s3='my.id123@gmail.com'
# sequence=array python also conatin negative index

# %%
s1='hello'
print(s1[-2])
print(s1)
print(len(s1))
for i in s1:
        print(i,end=' ')
# Out:
# l
# hello
# 5
# h e l l o

# %% [markdown]
# ## String literals
# 1. s1="Hello"
# 2. s2='Hello'
# 3. s3='''Hello'''
# 4. s4"""Hello
#         How are you?"""   for multiple line
